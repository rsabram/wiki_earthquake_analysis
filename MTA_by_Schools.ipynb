# %% [markdown]
# # Antioch (37013) has the highest number of schools in MNPS, with a total of 40 schools. Do the MTA routes in Antioch match up with the locations of the schools in Antioch?

# %%
import fontawesome as fa

# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# appnope                            0.1.0
# backports-abc                      0.5
# backports.functools-lru-cache      1.5
# backports.shutil-get-terminal-size 1.0.0
# bleach                             2.1.4
# branca                             0.3.0
# certifi                            2018.8.24
# chardet                            3.0.4
# Click                              7.0
# click-plugins                      1.0.4
# cligj                              0.4.0
# configparser                       3.5.0
# cycler                             0.10.0
# decorator                          4.3.0
# defusedxml                         0.5.0
# entrypoints                        0.2.3
# enum34                             1.1.6
# Fiona                              1.7.13
# folium                             0.6.0
# fontawesome                        5.3.1.post1
# functools32                        3.2.3.post2
# futures                            3.2.0
# geopandas                          0.4.0
# html5lib                           1.0.1
# idna                               2.7
# ipaddress                          1.0.22
# ipykernel                          4.9.0
# ipython                            5.8.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.4.2
# Jinja2                             2.10
# jsonschema                         2.6.0
# jupyter                            1.0.0
# jupyter-client                     5.2.3
# jupyter-console                    5.2.0
# jupyter-core                       4.4.0
# kiwisolver                         1.0.1
# MarkupSafe                         1.0
# matplotlib                         2.2.3
# mistune                            0.8.3
# munch                              2.3.2
# nbconvert                          5.4.0
# nbformat                           4.4.0
# notebook                           5.7.0
# numpy                              1.15.2
# pandas                             0.23.4
# pandocfilters                      1.4.2
# pathlib2                           2.3.2
# pexpect                            4.6.0
# pickleshare                        0.7.5
# pip                                18.0
# prometheus-client                  0.3.1
# prompt-toolkit                     1.0.15
# ptyprocess                         0.6.0
# Pygments                           2.2.0
# pypandoc                           1.4
# pyparsing                          2.2.1
# pyproj                             1.9.5.1
# python-dateutil                    2.7.3
# pytz                               2018.5
# pyzmq                              17.1.2
# qtconsole                          4.4.1
# requests                           2.19.1
# Rtree                              0.8.3
# scandir                            1.9.0
# Send2Trash                         1.5.0
# setuptools                         40.4.3
# Shapely                            1.6.4.post2
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.11.0
# subprocess32                       3.5.2
# terminado                          0.8.1
# testpath                           0.3.1
# tornado                            5.1.1
# traitlets                          4.3.2
# urllib3                            1.23
# wcwidth                            0.1.7
# webencodings                       0.5.1
# wheel                              0.31.1
# widgetsnbextension                 3.4.2

# %%
zipcode = gpd.read_file('/Users/rabram/Desktop/NSS/Nashville-Public-Art/data/Zip Codes (GIS).geojson')

# %%
mta = pd.read_csv('/Users/rabram/Desktop/NSS/Nashville-Public-Art/data/Metro_Transit_Authority_Bus_Stops.csv')

# %%
zipcode.head()
# Out:
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37027       34  BRENTWOOD   3140.581074908484  595244.46435546875
# 1  37027       37  BRENTWOOD  3558.4949049555025  315672.26501464844
# 2  37143       29     PEGRAM   7053.537934957626   1901096.087890625
# 3  37143       28     PEGRAM  1197.1070870572601  83126.842468261719
# 4  37240       44  NASHVILLE  9240.7969963306841  3146698.6988525391
#
#                                             geometry
# 0  (POLYGON ((-86.684745973484 35.992792089723, -...
# 1  (POLYGON ((-86.719974241412 36.009524281615, -...
# 2  (POLYGON ((-87.03537311557 36.087623620297, -8...
# 3  (POLYGON ((-87.03605109734001 36.095325458066,...
# 4  (POLYGON ((-86.803254434485 36.149298486807, -...

# %%
mta.head()
# Out:
#    Stop ID Number Stop Abbreviation                         StopName  Shelter  \
# 0            1788           100OAKS                    100 OAKS MALL        1
# 1            1792          POWPOWNM        POWELL AVE & POWELL PL NB        0
# 2            1785          BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0
# 3            1787          BRABERNM      BRANSFORD AVE & BERRY RD NB        0
# 4             461          BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0
#
#    Bench  Route Number Route Name  Longitude   Latitude  \
# 0      1             1  VINE HILL -86.762639  36.106851
# 1      0             1  VINE HILL -86.765569  36.108232
# 2      1             1  VINE HILL -86.766280  36.116603
# 3      0             1  VINE HILL -86.765494  36.121603
# 4      0             1  VINE HILL -86.765827  36.124624
#
#            Mapped Location
# 0  (36.106851, -86.762639)
# 1  (36.108232, -86.765569)
# 2  (36.116603, -86.766280)
# 3  (36.121603, -86.765494)
# 4  (36.124624, -86.765827)

# %%
mta.columns = ['stop_id', 'stop_abbrev','stop_name','shelter','bench','route_no','route_name',"lng",'lat','coordinates']

# %%
mta.head()
# Out:
#    stop_id stop_abbrev                        stop_name  shelter  bench  \
# 0     1788     100OAKS                    100 OAKS MALL        1      1
# 1     1792    POWPOWNM        POWELL AVE & POWELL PL NB        0      0
# 2     1785    BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0      1
# 3     1787    BRABERNM      BRANSFORD AVE & BERRY RD NB        0      0
# 4      461    BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0      0
#
#    route_no route_name        lng        lat              coordinates
# 0         1  VINE HILL -86.762639  36.106851  (36.106851, -86.762639)
# 1         1  VINE HILL -86.765569  36.108232  (36.108232, -86.765569)
# 2         1  VINE HILL -86.766280  36.116603  (36.116603, -86.766280)
# 3         1  VINE HILL -86.765494  36.121603  (36.121603, -86.765494)
# 4         1  VINE HILL -86.765827  36.124624  (36.124624, -86.765827)

# %%
mta['geometry'] = mta.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)

# %%
mta.head()
# Out:
#    stop_id stop_abbrev                        stop_name  shelter  bench  \
# 0     1788     100OAKS                    100 OAKS MALL        1      1
# 1     1792    POWPOWNM        POWELL AVE & POWELL PL NB        0      0
# 2     1785    BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0      1
# 3     1787    BRABERNM      BRANSFORD AVE & BERRY RD NB        0      0
# 4      461    BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0      0
#
#    route_no route_name        lng        lat              coordinates  \
# 0         1  VINE HILL -86.762639  36.106851  (36.106851, -86.762639)
# 1         1  VINE HILL -86.765569  36.108232  (36.108232, -86.765569)
# 2         1  VINE HILL -86.766280  36.116603  (36.116603, -86.766280)
# 3         1  VINE HILL -86.765494  36.121603  (36.121603, -86.765494)
# 4         1  VINE HILL -86.765827  36.124624  (36.124624, -86.765827)
#
#                                geometry
# 0  POINT (-86.76263900000001 36.106851)
# 1          POINT (-86.765569 36.108232)
# 2  POINT (-86.76628000000001 36.116603)
# 3  POINT (-86.76549399999999 36.121603)
# 4          POINT (-86.765827 36.124624)

# %%
mta_geo = gpd.GeoDataFrame(mta, crs = zipcode.crs, geometry = mta['geometry'])

# %%
mta_zip = gpd.sjoin(mta_geo, zipcode, op = 'within')

# %%
schools = pd.read_csv('/Users/rabram/Desktop/NSS/Nashville-Public-Art/data/Metro_Nashville_Public_School_Locations.csv')

# %%
schools.columns = ['SID','name','address','city','state','zip','phone','SSID','type','lowest_grade','highest_grade','lat','lng','website',"cluster","coordinates"]

# %%
schools['geometry'] = schools.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)

# %%
schools_geo = gpd.GeoDataFrame(schools, crs = zipcode.crs, geometry = schools['geometry'])

# %%
schools_geo[['zip', 'name']].groupby('zip').agg('count').sort_values(by ='name', ascending = False)
# Out:
#        name
# zip
# 37013    40
# 37207    32
# 37211    30
# 37209    30
# 37206    24
# 37214    18
# 37210    18
# 37216    16
# 37208    16
# 37115    16
# 37217    12
# 37203    12
# 37076    10
# 37218     8
# 37205     8
# 37204     6
# 37220     6
# 37138     6
# 37215     6
# 37072     6
# 37221     4
# 37212     4
# 37080     4
# 37189     4
# 37027     2
# 37228     2

# %%
schools37013 = schools_geo.loc[schools_geo['zip'] == 37013]

# %%
mta37013 = mta_zip.loc[mta_zip['zip'] == '37013']

# %%
mta37013.head()
# Out:
#       stop_id stop_abbrev                          stop_name  shelter  bench  \
# 1064      420    BELMORSN    BELL RD & MORRIS GENTRY BLVD SB        0      0
# 1065      421    BELMORSM    BELL RD & MORRIS GENTRY BLVD SB        0      1
# 1066      432    BELBELSF         BELL RD & BELL CREST DR SB        0      1
# 1067      413    BELHHIWF  BELL RD & HICKORY HIGHLANDS DR WB        0      0
# 1068      414    BELHICWN   BELL RD & HICKORY HOLLOW TER. WB        0      0
#
#       route_no         route_name        lng        lat  \
# 1064        15  MURFREESBORO ROAD -86.636764  36.066713
# 1065        15  MURFREESBORO ROAD -86.637206  36.064767
# 1066        15  MURFREESBORO ROAD -86.637948  36.062500
# 1067        15  MURFREESBORO ROAD -86.640854  36.059958
# 1068        15  MURFREESBORO ROAD -86.646236  36.051240
#
#                   coordinates                              geometry  \
# 1064  (36.066713, -86.636764)          POINT (-86.636764 36.066713)
# 1065  (36.064767, -86.637206)  POINT (-86.63720600000001 36.064767)
# 1066  (36.062500, -86.637948)    POINT (-86.63794799999999 36.0625)
# 1067  (36.059958, -86.640854)          POINT (-86.640854 36.059958)
# 1068  (36.051240, -86.646236)           POINT (-86.646236 36.05124)
#
#       index_right    zip objectid  po_name      shape_stlength  \
# 1064           42  37013       41  ANTIOCH  345351.56322143978
# 1065           42  37013       41  ANTIOCH  345351.56322143978
# 1066           42  37013       41  ANTIOCH  345351.56322143978
# 1067           42  37013       41  ANTIOCH  345351.56322143978
# 1068           42  37013       41  ANTIOCH  345351.56322143978
#
#            shape_starea
# 1064  1154549440.203186
# 1065  1154549440.203186
# 1066  1154549440.203186
# 1067  1154549440.203186
# 1068  1154549440.203186

# %%
zip_poly = zipcode.loc[zipcode.zip == '37013']

# %%
zip_poly.geometry.centroid
# Out:
# 42    POINT (-86.63636274154366 36.04173095575453)
# dtype: object

# %%
center37013 = [36.04173095575453, -86.63636274154366]

# %%
ax = zip_poly.plot(figsize = (10, 10), color = '#FFE8E5')
mta37013.plot( ax = ax, legend = True, color = '#CC2C12');

# %%
schools = pd.read_csv('/Users/rabram/Desktop/NSS/Nashville-Public-Art/data/Metro_Nashville_Public_School_Locations.csv')

# %%
schools.columns = ['SID','name','address','city','state','zip','phone','SSID','type','lowest_grade','highest_grade','lat','lng','website',"cluster","coordinates"]

# %%
schools.zip.value_counts(dropna = False)
# Out:
# 37013    40
# 37207    32
# 37211    30
# 37209    30
# 37206    24
# 37214    18
# 37210    18
# 37216    16
# 37208    16
# 37115    16
# 37203    12
# 37217    12
# 37076    10
# 37218     8
# 37205     8
# 37072     6
# 37138     6
# 37220     6
# 37204     6
# 37215     6
# 37189     4
# 37221     4
# 37080     4
# 37212     4
# 37027     2
# 37228     2
# Name: zip, dtype: int64

# %%
schools['geometry'] = schools.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)

# %%
schools_geo = gpd.GeoDataFrame(schools, crs = zipcode.crs, geometry = schools['geometry'])

# %%
schools37013 = schools_geo.loc[schools_geo['zip'] == 37013]

# %%
schools37013.head()
# Out:
#     SID                             name                    address     city  \
# 0   496          A. Z. Kelley Elementary           5834 Pettus Road  Antioch
# 4   110              Antioch High School           1900 Hobson Pike  Antioch
# 5   111                   Antioch Middle        5050 Blue Hole Road  Antioch
# 6   577                    Apollo Middle            631 Richards Rd  Antioch
# 12  419  Cambridge Early Learning Center  2325 Hickory Highlands Dr  Antioch
#
#    state    zip          phone  SSID               type lowest_grade  \
# 0     TN  37013  (615)941-7535     1  Elementary School     Grade P3
# 4     TN  37013  (615)641-5400    20        High School      Grade 9
# 5     TN  37013  (615)333-5642    23      Middle School      Grade 5
# 6     TN  37013  (615)333-5025    25      Middle School      Grade 5
# 12    TN  37013  (615)687-4560  7005  Elementary School     Grade P4
#
#    highest_grade        lat        lng  \
# 0        Grade 4  36.021817 -86.658848
# 4       Grade 12  36.046675 -86.599418
# 5        Grade 8  36.055379 -86.671830
# 6        Grade 8  36.066878 -86.664070
# 12      Grade P4  36.060350 -86.641017
#
#                                               website     cluster  \
# 0   http://schools.mnps.org/az-kelley-elementary-s...  Cane Ridge
# 4         http://schools.mnps.org/antioch-high-school     Antioch
# 5         http://schools.mnps.org/antioch-middle-prep  Cane Ridge
# 6          http://schools.mnps.org/apollo-middle-prep     Antioch
# 12  http://schools.mnps.org/cambridge-early-learni...         NaN
#
#                     coordinates                                geometry
# 0   (36.02181712, -86.65884778)        POINT (-86.65884778 36.02181712)
# 4   (36.04667464, -86.59941833)  POINT (-86.59941833000001 36.04667464)
# 5   (36.05537897, -86.67182989)        POINT (-86.67182989 36.05537897)
# 6   (36.06687798, -86.66406971)  POINT (-86.66406971000001 36.06687798)
# 12  (36.06035009, -86.64101743)  POINT (-86.64101743000001 36.06035009)

# %%
map_37013 = folium.Map(location = center37013, zoom_start = 12)
folium.GeoJson(zip_poly).add_to(map_37013)

for row in mta37013.iterrows():
    row_values = row[1] 
    location = [row_values['lat'], row_values['lng']]
    popup = (str(row_values['stop_name']))
    marker = folium.Marker(location = location, popup = popup, icon=folium.Icon(color='green',icon='bus', prefix='fa'))
    
    marker.add_to(map_37013)

for row in schools37013.iterrows():
    row_values = row[1] 
    location = [row_values['lat'], row_values['lng']]
    popup = (str(row_values['name'] + ', ' + str(row_values['type'])))
    marker = folium.Marker(location = location, popup = popup, icon=folium.Icon(color='red',icon='bell', icon_color='white', prefix='fa'))
    
    marker.add_to(map_37013)
    

map_37013
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## There are bus stops within immediate walking distance of:
# - Intrepid College Prep
# - Cambridge Early Learning Center
# - Apollo Middle School
# - J.E. Moss Elementary
#
# ## There are bus stops within moderate walking distance of:
# - Cole Elementary
# - Knowledge Academy
# - Smith Spring Elementary School
# - The Academy at Hickory Hollow

# %% [markdown]
# # Only 20% of MNPS schools in Antioch are accessible by MTA.

# %% [markdown]
# extension:

# %% [markdown]
# # Why does this matter? Let's look at TVAAS data for MNPS.

# %% [markdown]
# ### The Tennessee Value-Added Assessment System (TVAAS) measures student growth year over year, regardless of whether the student is proficient on the state assessment. In calculating a TVAAS score, a student’s performance is compared relative to the performance of his or her peers who have performed similarly on past assessments.

# %% [markdown]
# source: https://www.tn.gov/education/data/tvaas.html

# %%
tvaas = pd.read_csv('/Users/rabram/Desktop/NSS/Nashville-Public-Art/data/data_2018_TVAAS_School_Composite.csv')

# %%
tvaas.head()
# Out:
#    District Number  School Number    District Name  \
# 0               10              2  Anderson County
# 1               10              5  Anderson County
# 2               10             10  Anderson County
# 3               10             15  Anderson County
# 4               10             20  Anderson County
#
#                    School Name  Overall Composite  Literacy Composite  \
# 0  Anderson County High School                  5                 1.0
# 1     Andersonville Elementary                  5                 4.0
# 2        Briceville Elementary                  5                 4.0
# 3           Claxton Elementary                  5                 3.0
# 4        Clinton Middle School                  1                 1.0
#
#    Numeracy Composite  Literacy and Numeracy Composite  Science Composite  \
# 0                 5.0                                3                5.0
# 1                 5.0                                5                5.0
# 2                 4.0                                4                5.0
# 3                 5.0                                5                5.0
# 4                 3.0                                1                1.0
#
#    Social Studies Composite
# 0                       1.0
# 1                       4.0
# 2                       3.0
# 3                       1.0
# 4                       1.0

# %%
tvaas.columns = ['district_no','school_no','district','school','overall','lit','numeracy','lit_and_numeracy','science','ss']

# %%
tvaas_nashville = tvaas.loc[tvaas.district == "Davidson County"]

# %%
tvaas_nashville.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 234 to 387
# Data columns (total 10 columns):
# district_no         154 non-null int64
# school_no           154 non-null int64
# district            154 non-null object
# school              154 non-null object
# overall             154 non-null int64
# lit                 153 non-null float64
# numeracy            154 non-null float64
# lit_and_numeracy    154 non-null int64
# science             76 non-null float64
# ss                  75 non-null float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 13.2+ KB

# %%
tvaas_zip = pd.merge(tvaas_nashville, schools_geo, left_on = "school",right_on = "name")

# %%
tvaas_zip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 0 to 279
# Data columns (total 27 columns):
# district_no         280 non-null int64
# school_no           280 non-null int64
# district            280 non-null object
# school              280 non-null object
# overall             280 non-null int64
# lit                 278 non-null float64
# numeracy            280 non-null float64
# lit_and_numeracy    280 non-null int64
# science             134 non-null float64
# ss                  132 non-null float64
# SID                 280 non-null int64
# name                280 non-null object
# address             280 non-null object
# city                280 non-null object
# state               280 non-null object
# zip                 280 non-null int64
# phone               280 non-null object
# SSID                280 non-null int64
# type                280 non-null object
# lowest_grade        280 non-null object
# highest_grade       280 non-null object
# lat                 280 non-null float64
# lng                 280 non-null float64
# website             280 non-null object
# cluster             190 non-null object
# coordinates         280 non-null object
# geometry            280 non-null object
# dtypes: float64(6), int64(7), object(14)
# memory usage: 61.2+ KB

# %%
del tvaas_zip['SSID']
del tvaas_zip['type']
del tvaas_zip['lowest_grade']
del tvaas_zip['highest_grade']

# %%
del tvaas_zip['phone']
del tvaas_zip['website']
del tvaas_zip['science']
del tvaas_zip['ss']

# %%
tvaas_zip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 0 to 279
# Data columns (total 19 columns):
# district_no         280 non-null int64
# school_no           280 non-null int64
# district            280 non-null object
# school              280 non-null object
# overall             280 non-null int64
# lit                 278 non-null float64
# numeracy            280 non-null float64
# lit_and_numeracy    280 non-null int64
# SID                 280 non-null int64
# name                280 non-null object
# address             280 non-null object
# city                280 non-null object
# state               280 non-null object
# zip                 280 non-null int64
# lat                 280 non-null float64
# lng                 280 non-null float64
# cluster             190 non-null object
# coordinates         280 non-null object
# geometry            280 non-null object
# dtypes: float64(4), int64(6), object(9)
# memory usage: 43.8+ KB

# %%
tvaas_zip.head()
# Out:
#    district_no  school_no         district                   school  overall  \
# 0          190          1  Davidson County  A. Z. Kelley Elementary        1
# 1          190          1  Davidson County  A. Z. Kelley Elementary        1
# 2          190          5  Davidson County    Alex Green Elementary        3
# 3          190          5  Davidson County    Alex Green Elementary        3
# 4          190         10  Davidson County         Amqui Elementary        3
#
#    lit  numeracy  lit_and_numeracy  SID                     name  \
# 0  1.0       1.0                 1  496  A. Z. Kelley Elementary
# 1  1.0       1.0                 1  496  A. Z. Kelley Elementary
# 2  3.0       3.0                 3  375    Alex Green Elementary
# 3  3.0       3.0                 3  375    Alex Green Elementary
# 4  3.0       2.0                 3  105         Amqui Elementary
#
#              address          city state    zip        lat        lng  \
# 0   5834 Pettus Road       Antioch    TN  37013  36.021817 -86.658848
# 1   5834 Pettus Road       Antioch    TN  37013  36.021817 -86.658848
# 2    3921 Lloyd Road  Whites Creek    TN  37189  36.252961 -86.832229
# 3    3921 Lloyd Road  Whites Creek    TN  37189  36.252961 -86.832229
# 4  319 Anderson Lane       Madison    TN  37115  36.273766 -86.703832
#
#         cluster                  coordinates                          geometry
# 0    Cane Ridge  (36.02181712, -86.65884778)  POINT (-86.65884778 36.02181712)
# 1    Cane Ridge  (36.02181712, -86.65884778)  POINT (-86.65884778 36.02181712)
# 2  Whites Creek    (36.2529607, -86.8322292)    POINT (-86.8322292 36.2529607)
# 3  Whites Creek    (36.2529607, -86.8322292)    POINT (-86.8322292 36.2529607)
# 4  Hunters Lane  (36.27376585, -86.70383153)  POINT (-86.70383153 36.27376585)

# %%
del tvaas_zip['SID']
del tvaas_zip['name']
del tvaas_zip['address']
del tvaas_zip['city']
del tvaas_zip['state']

# %%
tvaas_zip.head()
# Out:
#    district_no  school_no         district                   school  overall  \
# 0          190          1  Davidson County  A. Z. Kelley Elementary        1
# 1          190          1  Davidson County  A. Z. Kelley Elementary        1
# 2          190          5  Davidson County    Alex Green Elementary        3
# 3          190          5  Davidson County    Alex Green Elementary        3
# 4          190         10  Davidson County         Amqui Elementary        3
#
#    lit  numeracy  lit_and_numeracy    zip        lat        lng       cluster  \
# 0  1.0       1.0                 1  37013  36.021817 -86.658848    Cane Ridge
# 1  1.0       1.0                 1  37013  36.021817 -86.658848    Cane Ridge
# 2  3.0       3.0                 3  37189  36.252961 -86.832229  Whites Creek
# 3  3.0       3.0                 3  37189  36.252961 -86.832229  Whites Creek
# 4  3.0       2.0                 3  37115  36.273766 -86.703832  Hunters Lane
#
#                    coordinates                          geometry
# 0  (36.02181712, -86.65884778)  POINT (-86.65884778 36.02181712)
# 1  (36.02181712, -86.65884778)  POINT (-86.65884778 36.02181712)
# 2    (36.2529607, -86.8322292)    POINT (-86.8322292 36.2529607)
# 3    (36.2529607, -86.8322292)    POINT (-86.8322292 36.2529607)
# 4  (36.27376585, -86.70383153)  POINT (-86.70383153 36.27376585)

# %%
tvaas_zip = tvaas_zip.drop_duplicates(subset='school')

# %%
tvaas_zip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 278
# Data columns (total 14 columns):
# district_no         140 non-null int64
# school_no           140 non-null int64
# district            140 non-null object
# school              140 non-null object
# overall             140 non-null int64
# lit                 139 non-null float64
# numeracy            140 non-null float64
# lit_and_numeracy    140 non-null int64
# zip                 140 non-null int64
# lat                 140 non-null float64
# lng                 140 non-null float64
# cluster             95 non-null object
# coordinates         140 non-null object
# geometry            140 non-null object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 16.4+ KB

# %%
tvaas_zip.describe()
# Out:
#        district_no    school_no    overall         lit    numeracy  \
# count        140.0   140.000000  140.00000  139.000000  140.000000
# mean         190.0  1690.992857    2.80000    3.172662    2.585714
# std            0.0  2902.712020    1.66297    1.498444    1.502926
# min          190.0     1.000000    1.00000    1.000000    1.000000
# 25%          190.0   258.750000    1.00000    2.000000    1.000000
# 50%          190.0   447.500000    3.00000    3.000000    2.500000
# 75%          190.0   651.250000    5.00000    5.000000    4.000000
# max          190.0  8100.000000    5.00000    5.000000    5.000000
#
#        lit_and_numeracy          zip         lat         lng
# count        140.000000    140.00000  140.000000  140.000000
# mean           2.871429  37176.05000   36.152830  -86.747206
# std            1.590633     67.87635    0.070946    0.075500
# min            1.000000  37013.00000   36.020174  -86.958050
# 25%            1.000000  37203.00000   36.095895  -86.798722
# 50%            3.000000  37208.00000   36.154653  -86.743416
# 75%            4.250000  37211.00000   36.196445  -86.707816
# max            5.000000  37228.00000   36.318151  -86.578658

# %% [markdown]
# ## The  average TVAAS score for MNPS schools are:
# - Overall: 2.80
# - Literacy: 3.17
# - Math: 2.38
# - Math & Reading: 2.87

# %%
tvaas37013 = tvaas_zip.loc[tvaas_zip['zip'] == 37013]

# %%
tvaas37013.overall.value_counts(dropna = False)
# Out:
# 1    7
# 3    4
# 5    2
# 4    1
# Name: overall, dtype: int64

# %%
tvaas37013_low = tvaas37013.nsmallest(7, 'overall')

# %%
tvaas37013_low.school
# Out:
# 0              A. Z. Kelley Elementary
# 8                  Antioch High School
# 12                       Apollo Middle
# 24              Cane Ridge High School
# 56         Thomas A. Edison Elementary
# 200           Thurgood Marshall Middle
# 268    Knowledge Academies High School
# Name: school, dtype: object

# %% [markdown]
# ## In Antioch in 2017-2018,  7 schools have a 1 for their overall TVAAS score and are below the MNPS average. 5 of these 7 schools are inacessible to parents, families, and students by MTA.

# %% [markdown]
# ### "Building strong parent-school relationships is another way to increase school and student outcomes."
#
# "One study defined parent-school relationships by the degree to which parents trust staff, have
# positive interactions with staff, and feel welcome at the school. This study used data from the National
# Household Education Surveys Program of 2007: Parent and Family Involvement in Education Survey,
# which collected data from across the United States. This study restricted data use to students in sixth
# through twelfth grades. Data for parent-school relationships and student outcomes were gathered
# through parent interviews. Results from SEM revealed that all three aspects of this parent-school
# relationship were positively associated with student outcomes (i.e., estimates of students’ grades,
# report of students’ problem behaviors at school, report of whether students had to repeat a grade)
# (Froiland & Davison, 2014)." Source: https://www.nmefoundation.org/getattachment/67f7c030-df45-4076-a23f-0d7f0596983f/Final-Report-Family-Engagement-AIR.pdf?lang=en-US&ext=.pdf

# %% [markdown]
# ## In Antioch, 5 of the lowest performing schools are inaccessible by MTA.
#
# ## In Antioch, nearly 40% of families have an average household income of less than $25,000.
#
# source: https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-2015-zip-code-data-soi
# ### Families with low household incomes tend to rely on MTA for transportation, suggesting that up to 40% of Antioch families rely on MTA. If these families are unable to physically get to their student's school, it becomes significantly more difficult to build strong parent-school relationships. They cannot have the positive interactions necessary to build trust and feel welcome at the school if they are never physcially in the building.
#
# ## These inaccesible schools in Antioch (AZ Kelley, Antioch HS, Cane Ridge, Thomas Edison, and Thurgood Marshall) are unable to see an increase in overall in TVAAS scores due to family engagement.

# %%
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
#  |      See Font-Awesome website to choose yours.
#  |      Warning : depending on the icon you choose you may need to adapt
#  |      the `prefix` as well.
#  |  angle : int, default 0
#  |      The icon will be rotated by this amount of degrees.
#  |  prefix : str, default 'glyphicon'
#  |      The prefix states the source of the icon. 'fa' for font-awesome or
#  |      'glyphicon' for bootstrap 3.
#  |
#  |
#  |  https://github.com/lvoogdt/Leaflet.awesome-markers
#  |
#  |  Method resolution order:
#  |      Icon
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, color='blue', icon_color='white', icon='info-sign', angle=0, prefix='glyphicon')
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.MacroElement:
#  |
#  |  render(self, **kwargs)
#  |      Renders the HTML representation of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  add_child(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_children(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_to(self, parent, name=None, index=None)
#  |      Add element to a parent.
#  |
#  |  get_bounds(self)
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self)
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self)
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile, close_file=True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth=-1, ordered=True, **kwargs)
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth=-1, **kwargs)
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
